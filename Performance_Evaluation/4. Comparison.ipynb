# %% [markdown]
# <a href="https://colab.research.google.com/github/ttezy/Time-Sequence-Analysis/blob/main/Performance_Evaluation/4.%20Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import lib**

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # **Load performance data**

# %% [markdown]
# You may need to upload 'performance.csv' to '/content/performance.csv' first if you are using google colab

# %%
performance = pd.read_csv('/content/performance.csv', header=0, index_col='futureStep').drop(['Unnamed: 0'], axis='columns')
performance
# Out:
#             LSTM_train_time  LSTM_pred_time  ...  Prophet_pred_time  Prophet_RMSE
# futureStep                                   ...
# 1                105.876651        0.585758  ...           2.827908     15.635074
# 2                 87.481275        0.531446  ...           2.783116     20.277924
# 3                 90.200571        0.586707  ...           2.760743     24.225334
# 4                 87.507864        0.497406  ...           2.864759     26.992872
# 5                144.578841        0.550200  ...           2.914824     28.599872
# 6                144.036165        0.581201  ...           2.744648     33.888291
# 7                 87.991832        0.540688  ...           2.948139     32.226575
# 8                 87.094941        0.504986  ...           2.740763     32.730049
# 9                144.055997        0.535396  ...           2.858718     34.879333
# 10                95.500659        0.585587  ...           2.757308     40.414856
# ...

# %% [markdown]
# # **Plot Training time, Prediction time and RMSE**

# %%
plt.figure(figsize=(15, 5))
plt.plot(performance['LSTM_train_time'], label='LSTM training time')
plt.plot(performance['VAR_train_time'], label='VAR training time')
plt.plot(performance['Prophet_train_time'], label='Prophet training time')
plt.title("Training time(The smaller the training time is, the faster the algorithm is, which means better.)")
plt.xlabel('future step')
plt.ylabel('second')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
plt.plot(performance['LSTM_pred_time'], label='LSTM prediction time')
plt.plot(performance['VAR_pred_time'], label='VAR prediction time')
plt.plot(performance['Prophet_pred_time'], label='Prophet prediction time')
plt.title("Prediction time(The smaller the prediction time is, the faster the algorithm is, which means better.)")
plt.xlabel('future step')
plt.ylabel('second')
plt.legend()
plt.show()

plt.figure(figsize=(15, 5))
plt.plot(performance['LSTM_RMSE'], label='LSTM RMSE')
plt.plot(performance['VAR_RMSE'], label='VAR RMSE')
plt.plot(performance['Prophet_RMSE'], label='Prophet RMSE')
plt.title("RMSE(The lower the RMSE is, the more accurate the algorithm is, which means the prediction is closer to the ground truth.)")
plt.xlabel('future step')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %% [markdown]
# Note: The FB Prophet seems having the best accuracies, but to forecast data by FB Prophet for more than one future steps, we need to predict all variables first. One output y is only corresponding to one row of variable.
